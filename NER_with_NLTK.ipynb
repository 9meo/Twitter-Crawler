# %%
from nltk import ne_chunk, pos_tag, word_tokenize

# %%
from nltk.tree import Tree
import re
from langdetect import detect_langs

# %%
def get_continuous_chunks(text):
    chunked = ne_chunk(pos_tag(word_tokenize(text)))
    prev = None
    continuous_chunk = []
    current_chunk = []

    for i in chunked:
        if type(i) == Tree:
            current_chunk.append(" ".join([token for token, pos in i.leaves()]))
        elif current_chunk:
            named_entity = " ".join(current_chunk)
            if named_entity not in continuous_chunk:
                continuous_chunk.append(named_entity)
                current_chunk = []
        else:
            continue

    if continuous_chunk:
        named_entity = " ".join(current_chunk)
        if named_entity not in continuous_chunk:
            continuous_chunk.append(named_entity)

    return continuous_chunk

# %%
def removeEmoji(text):
    emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'',text)

# %%
def cleantext(text):
    res = ''
    for s in text.split():
        if  s.startswith('@') or  s.startswith('#') or s.startswith('RT@') or s=='RT' or s.startswith('http') : 
            continue
        else:   
            res +=  s + ' '
    return res

# %%
def isEnglish(string):
    try: 
        res = detect_langs(string)
    except Exception as e:
        return False
    for item in res:
        if item.lang == "en":
            return True
    return False

# %%
txt = "RT @VintageUV: Come on England. #worldcup #worldcup2018 #england #ourboys #vintage #russia #believe #comeonengland #football https://t.co/a…" 
txt = cleantext(removeEmoji(txt))
print(isEnglish(txt))
# Out:
# True

# %%
f = open('stream_text.txt','r',encoding='utf-8')
f.close()

# %%
tweets = list(open('stream_text_all.txt','r',encoding='utf-8').read().splitlines())
print(len(tweets))
tweets = list(set(tweets))
print(len(tweets))
# Out:
# 21886
# 11627

# %%
all_nes =[]
for tw in tweets:
    data = cleantext(removeEmoji(tw))
    if(len(data)<3):
        continue
    nes = []
    if(isEnglish(data)):
        nes = get_continuous_chunks(data)
        all_nes.extend(nes)

# %%
from collections import Counter
x=Counter(all_nes)
x.most_common()
# Out:
# [('', 4316),
#  ('Russia', 1047),
#  ('FIFA', 723),
#  ('England', 204),
#  ('Saudi Arabia', 171),
#  ('Happy', 109),
#  ('New', 65),
#  ('Brazil', 61),
#  ('FREE', 56),
#  ('Germany', 52),
#  ('Good', 51),
#  ('Moscow', 51),
#  ('Spain', 51),
#  ('Football', 47),
#  ('Russian', 47),
#  ('Argentina', 44),
#  ('BETBRIGHT Offer Deposit', 43),
#  ('BETBRIGHT Offer Double', 42),
#  ('CORAL', 41),
#  ('QUESTIONS CORRECTLY', 41),
#  ('Which', 39),
#  ('France', 37),
#  ('Saudi', 37),
#  ('Nigeria', 35),
#  ('Portugal', 30),
#  ('Fifa', 29),
#  ('Iran', 26),
#  ('Ready', 24),
#  ('English', 24),
#  ('Egypt', 23),
#  ('Golden', 23),
#  ('Messi', 23),
#  ('Great', 22),
#  ('UNIBET Offer Bet', 22),
#  ('Bundle', 22),
#  ('Super Eagles', 20),
#  ('Belgium', 20),
#  ('Bet', 19),
#  ('Scotland', 18),
#  ('Saudi Arabia New Customers', 17),
#  ('Christmas', 15),
#  ('African', 15),
#  ('Africa', 15),
#  ('Ball', 15),
#  ('Watch', 15),
#  ('RUSSIA', 15),
#  ('Match', 14),
#  ('Morocco', 14),
#  ('Don', 13),
#  ('Australia', 12),
#  ('Happy World', 12),
#  ('Robbie Williams', 12),
#  ('LIVE', 12),
#  ('WATCH', 12),
#  ('Nike', 12),
#  ('Italy', 12),
#  ('Putin', 12),
#  ('Ukraine', 12),
#  ('Kick', 12),
#  ('Tunisia', 12),
#  ('Anyone', 11),
#  ('Iceland', 11),
#  ('Love', 11),
#  ('Luzhniki Stadium', 11),
#  ('Click', 11),
#  ('Soccer', 11),
#  ('Bookish', 11),
#  ('Croatia', 11),
#  ('Mexico', 11),
#  ('Odds', 10),
#  ('Live', 10),
#  ('South Korea', 10),
#  ('Brackets', 10),
#  ('Senegal', 10),
#  ('Switzerland', 10),
#  ('Best', 10),
#  ('Unibet', 9),
#  ('Ronaldo', 9),
#  ('YOU', 9),
#  ('Free', 9),
#  ('Super', 9),
#  ('Enjoy', 9),
#  ('Roll', 9),
#  ('Panama', 9),
#  ('YOUR', 8),
#  ('Odds Boost', 8),
#  ('Bigger', 8),
#  ('Back Russia', 8),
#  ('Proludic Sports', 8),
#  ('Luzhniki', 8),
#  ('US', 8),
#  ('Who', 8),
#  ('Join', 8),
#  ('India', 8),
#  ('WORLD', 8),
#  ('USA', 8),
#  ('Schedules', 8),
#  ('Sorry', 8),
#  ('Leo Messi', 8),
#  ('BBC', 8),
#  ('ITV', 8),
#  ('Paul', 8),
#  ('Uruguay', 8),
#  ('Liverpool', 7),
#  ('Neymar', 7),
#  ('Nigerian', 7),
#  ('Official Video', 7),
#  ('Let', 7),
#  ('Neds', 7),
#  ('Tonight', 7),
#  ('VAR', 7),
#  ('Adidas', 7),
#  ('Ireland', 7),
#  ('ITS', 7),
#  ('Top Goalscorer', 7),
#  ('THE', 7),
#  ('Team', 7),
#  ('Chinese', 7),
#  ('Saudis', 7),
#  ('Simply', 7),
#  ('Argentine', 7),
#  ('Have', 7),
#  ('Download', 7),
#  ('German', 6),
#  ('HD Stream', 6),
#  ('Hello', 6),
#  ('Belarus', 6),
#  ('____', 6),
#  ('Chance', 6),
#  ('Peru', 6),
#  ('Russians', 6),
#  ('Islamic', 6),
#  ('UK', 6),
#  ('WC', 6),
#  ('WorldCup2018', 6),
#  ('Tim Cahill', 6),
#  ('Good Luck', 6),
#  ('HOT', 6),
#  ('Colombia', 6),
#  ('Please', 6),
#  ('Come', 6),
#  ('Winner', 6),
#  ('WORLDCUP', 6),
#  ('Britain', 6),
#  ('WAIT', 6),
#  ('Goal', 6),
#  ('Okay', 6),
#  ('Host', 6),
#  ('London', 6),
#  ('Austria', 6),
#  ('NEW', 6),
#  ('Germans', 6),
#  ('Kicks', 6),
#  ('Love Island', 6),
#  ('Hope', 6),
#  ('ENGLAND', 6),
#  ('BET', 6),
#  ('Ukrainian', 6),
#  ('Jersey', 5),
#  ('Claim', 5),
#  ('Twitter', 5),
#  ('Three Lions', 5),
#  ('First', 5),
#  ('Group A', 5),
#  ('Syria', 5),
#  ('VIDEOS', 5),
#  ('AUSTRALIA WIN', 5),
#  ('Bonus Bet', 5),
#  ('Saudi Arabi', 5),
#  ('George', 5),
#  ('TOKYO', 5),
#  ('Group C', 5),
#  ('Cristiano Ronaldo', 5),
#  ('Achilles', 5),
#  ('Vladimir Putin', 5),
#  ('Town', 5),
#  ('Might', 5),
#  ('PDFsposters', 5),
#  ('Gareth Southgate', 5),
#  ('Saudi Arabian', 5),
#  ('Serbia', 5),
#  ('South', 5),
#  ('Hey', 5),
#  ('FIRST', 5),
#  ('Socceroos', 5),
#  ('Lionel Messi', 5),
#  ('SW China', 5),
#  ('FOOTBALL', 5),
#  ('Poland', 5),
#  ('Retweet', 5),
#  ('Octopus', 5),
#  ('Russia Saudi Arabia', 4),
#  ('EuropeanParliament', 4),
#  ('Bundle New Customers', 4),
#  ('Mood', 4),
#  ('UBS', 4),
#  ('Spain Surprise', 4),
#  ('BIG', 4),
#  ('NEDS BONUS', 4),
#  ('Billion Lottery', 4),
#  ('Will', 4),
#  ('Kazan', 4),
#  ('Rejoice', 4),
#  ('Between Magical Pig', 4),
#  ('Eagles Destiny', 4),
#  ('Scottish', 4),
#  ('BLOCKBUSTER', 4),
#  ('Fortnite Battle Royale', 4),
#  ('Throwback', 4),
#  ('Golden Boot', 4),
#  ('Whose', 4),
#  ('Line', 4),
#  ('Make', 4),
#  ('Countdown', 4),
#  ('Dad', 4),
#  ('SUPER', 4),
#  ('Korea', 4),
#  ('Win £1 Million', 4),
#  ('IRE', 4),
#  ('Oleg Sentsov', 4),
#  ('Thank', 4),
#  ('World', 4),
#  ('Egyptian', 4),
#  ('Arabia', 4),
#  ('James Rodriguez', 4),
#  ('Massive', 4),
#  ('Football Fever', 4),
#  ('China', 4),
#  ('News', 4),
#  ('French', 4),
#  ('Fixtures', 4),
#  ('Code', 4),
#  ('Stay', 4),
#  ('Bet £20', 4),
#  ('Columbia', 4),
#  ('FIFA Brazil', 4),
#  ('Daily', 4),
#  ('COMING', 4),
#  ('United', 4),
#  ('Eagles', 4),
#  ('Stan', 4),
#  ('Share', 4),
#  ('Cheer', 4),
#  ('Logo', 4),
#  ('LADBROKES BONUS', 4),
#  ('FIRST GAME', 4),
#  ('Sweden', 4),
#  ('Motion', 4),
#  ('Fantasy League', 4),
#  ('Cool', 4),
#  ('British', 4),
#  ('Social Media', 3),
#  ('Arabic', 3),
#  ('Julen Lopetegui', 3),
#  ('Welcome FIFA', 3),
#  ('Well', 3),
#  ('Got', 3),
#  ('Group', 3),
#  ('Bet Online', 3),
#  ('RANKED', 3),
#  ('Ahmed Musa Eyes Perfect Start', 3),
#  ('Value Outside Bet Wildcard', 3),
#  ('Essam', 3),
#  ('Listen', 3),
#  ('Denmark', 3),
#  ('Cahill', 3),
#  ('Bedlington Cricket', 3),
#  ('Greatest', 3),
#  ('Suarez', 3),
#  ('Dybala', 3),
#  ('Betfred', 3),
#  ('Bet £10', 3),
#  ('Free Bets Visit Betfred', 3),
#  ('Marry', 3),
#  ('Google', 3),
#  ('HQ', 3),
#  ('Festival', 3),
#  ('Vindaloo', 3),
#  ('HOURS', 3),
#  ('Georgia', 3),
#  ('Smolensk', 3),
#  ('Timo Werner', 3),
#  ('National', 3),
#  ('Groups', 3),
#  ('Keep', 3),
#  ('Superb', 3),
#  ('Costa Rica', 3),
#  ('Kicks Off', 3),
#  ('Email', 3),
#  ('How', 3),
#  ('Hierro', 3),
#  ('BBC Sport', 3),
#  ('Ffs', 3),
#  ('Dutch', 3),
#  ('Sign', 3),
#  ('Group B', 3),
#  ('Leeds', 3),
#  ('Messi Expresses Fears', 3),
#  ('THE WORLD', 3),
#  ('Seeds', 3),
#  ('Basketmakers', 3),
#  ('Les', 3),
#  ('Japan', 3),
#  ('Watch France', 3),
#  ('EVERYONE', 3),
#  ('Lions', 3),
#  ('Coming Home', 3),
#  ('Win', 3),
#  ('Son', 3),
#  ('EVERY', 3),
#  ('Iraq', 3),
#  ('Oooohhh', 3),
#  ('Saudi Arabia Russia', 3),
#  ('HADİ CANIM', 3),
#  ('ISRARLA PARA', 3),
#  ('LGBT', 3),
#  ('Newbury', 3),
#  ('Horse Racing', 3),
#  ('Has', 3),
#  ('Official', 3),
#  ('Wales', 3),
#  ('Qatar', 3),
#  ('Fernando Hierro', 3),
#  ('Holland', 3),
#  ('Syndicate', 3),
#  ('Psychic Pig', 3),
#  ('Nigeria Will Get', 3),
#  ('LETS', 3),
#  ('National Team', 3),
#  ('Hexa', 3),
#  ('Disgraceful', 3),
#  ('Yogi', 3),
#  ('Happy FIFA', 3),
#  ('Irish', 3),
#  ('Kick Off', 3),
#  ('Group Stage', 3),
#  ('Pav', 3),
#  ('Jogger', 3),
#  ('See', 3),
#  ('Sports Lounge', 3),
#  ('Ramadan', 3),
#  ('James', 3),
#  ('Sichuan', 3),
#  ('KCCA', 3),
#  ('PORTUGAL', 3),
#  ('WIB', 3),
#  ('Robbie', 3),
#  ('TWO', 3),
#  ('Show', 3),
#  ('Sweepstake', 3),
#  ('Iranian', 3),
#  ('Link', 3),
#  ('Incredible', 3),
#  ('Harry', 3),
#  ('UOM', 3),
#  ('Students Union', 3),
#  ('Shenyang City', 3),
#  ('NE Liaoning Province', 3),
#  ('Dear', 3),
#  ('Middle East', 3),
#  ('Israeli', 3),
#  ('Gaza', 3),
#  ('Flyer', 3),
#  ('Rack Card', 3),
#  ('Business Card', 3),
#  ('Brochure', 3),
#  ('Letter Head', 3),
#  ('Web Banners', 3),
#  ('Psychic Bob', 3),
#  ('Fantastic', 3),
#  ('U.S.', 3),
#  ('Wizkid Joins Will Smith', 3),
#  ('Opening Ceremony', 3),
#  ('Photo', 3),
#  ('Latest Top', 3),
#  ('Google Doodle', 3),
#  ('Paddy Power', 3),
#  ('Russia-', 3),
#  ('N Over J', 3),
#  ('Zidane', 3),
#  ('Celebrate', 3),
#  ('Sport Halls', 3),
#  ('Outside Pitches', 3),
#  ('ALL', 3),
#  ('Bleacher Report', 3),
#  ('Beer', 3),
#  ('Home', 3),
#  ('African Teams', 3),
#  ('Say Amen', 3),
#  ('Stepan Chubenko', 3),
#  ('FreePlay6', 3),
#  ('Copy', 3),
#  ('Abit', 3),
#  ('XXL Ledbury', 3),
#  ('Adidas Telstar', 3),
#  ('Locker Room', 3),
#  ('Pidgin', 3),
#  ('Wow', 3),
#  ('Will Smith', 3),
#  ('Start Time', 3),
#  ('Live Stream', 3),
#  ('European', 3),
#  ('Nicky Jam', 3),
#  ('Italia', 3),
#  ('OFFERS', 3),
#  ('Tips', 3),
#  ('Data', 3),
#  ('STARTS', 3),
#  ('Group D', 3),
#  ('Parker', 3),
#  ('Bafana Bafana', 2),
#  ('Kid', 2),
#  ('Robert DeNiro', 2),
#  ('Eddie Murphy', 2),
#  ('Joe Pesci', 2),
#  ('Gordon Ramsay', 2),
#  ('Mark Wahlberg', 2),
#  ('Yep', 2),
#  ('Get', 2),
#  ('Wallchart Team', 2),
#  ('FAIRWAY', 2),
#  ('Vamos', 2),
#  ('Naira', 2),
#  ('iPredict', 2),
#  ('Acorn', 2),
#  ('Local', 2),
#  ('FINALLY', 2),
#  ('Dante', 2),
#  ('Scorer Tip', 2),
#  ('Champions League Final', 2),
#  ('ChampionsLeague', 2),
#  ('Behance', 2),
#  ('NOW', 2),
#  ('OF FOR A', 2),
#  ('MO SALAH', 2),
#  ('Belgium Biggest Flop', 2),
#  ('AUSTRALIA', 2),
#  ('Green Falcons', 2),
#  ('Does', 2),
#  ('Pretius Tournament', 2),
#  ('IPTV M3U', 2),
#  ('Damn', 2),
#  ('VIP TIPSTER', 2),
#  ('Lola', 2),
#  ('Katy Perry', 2),
#  ('OniPako', 2),
#  ('Sammy', 2),
#  ('Draxler', 2),
#  ('Aris', 2),
#  ('Saudi Arabia Esta', 2),
#  ('Exciting News', 2),
#  ('Official England', 2),
#  ('Song', 2),
#  ('Rare', 2),
#  ('Done', 2),
#  ('Melbourne', 2),
#  ('HIRING', 2),
#  ('Ed Klajman', 2),
#  ('Foodbank Bingo', 2),
#  ('Beer Festival', 2),
#  ('Cheeky', 2),
#  ('Life', 2),
#  ('DEPOSIT', 2),
#  ('Turnover', 2),
#  ('Promo Deposit', 2),
#  ('Bets', 2),
#  ('Longshots', 2),
#  ('Lewandovski', 2),
#  ('Me', 2),
#  ('Consumer', 2),
#  ('Chloe Whitelock', 2),
#  ('Huge', 2),
#  ('Comment', 2),
#  ('Mark', 2),
#  ('Terminal', 2),
#  ('REVENGE', 2),
#  ('Be', 2),
#  ('Perfect', 2),
#  ('Hi', 2),
#  ('ASTRO', 2),
#  ('NJOI', 2),
#  ('MYTV', 2),
#  ('Mark Milligan', 2),
#  ('Flawless', 2),
#  ('Union Diner', 2),
#  ('Xiao Wei Yang International City Branch', 2),
#  ('Paddy Power Bet', 2),
#  ('Outright Market', 2),
#  ('Saudi Arabia Live Stream Free', 2),
#  ('PS4', 2),
#  ('Festival Mall', 2),
#  ('Money Back', 2),
#  ('Entry Prizes', 2),
#  ('INR', 2),
#  ('Fantasy', 2),
#  ('Hyped', 2),
#  ('FANTASTIC', 2),
#  ('BOOKS', 2),
#  ('Part', 2),
#  ('Machine', 2),
#  ('Racism', 2),
#  ('Plz', 2),
#  ('Czech', 2),
#  ('Raptors', 2),
#  ('Sports Club', 2),
#  ('Saudi Arabia Opening Match', 2),
#  ('WorldCupRussia2018 Live Stream', 2),
#  ('Häfele UK', 2),
#  ('Mabesh', 2),
#  ('Nana Kwame Kissi', 2),
#  ('Yaw Sanogo', 2),
#  ('Gunners', 2),
#  ('Nikes', 2),
#  ('Group A-', 2),
#  ('SUMMER', 2),
#  ('KIDS Book', 2),
#  ('Buhari', 2),
#  ('LVP', 2),
#  ('Predict Full', 2),
#  ('Social', 2),
#  ('Wave', 2),
#  ('St. George', 2),
#  ('Babathai Restaurant', 2),
#  ('Bill Gates', 2),
#  ('Massacre MASSIF', 2),
#  ('Costa', 2),
#  ('Worldcup Rusia Join', 2),
#  ('Scots', 2),
#  ('Northern', 2),
#  ('BBC Arabic', 2),
#  ('GOLDEN', 2),
#  ('Crimea', 2),
#  ('American', 2),
#  ('Kerala', 2),
#  ('Can', 2),
#  ('Aida Garifullina', 2),
#  ('Always', 2),
#  ('Rubik', 2),
#  ('Cheeky Steak Sarnie', 2),
#  ('Cheeky Pint', 2),
#  ('Title', 2),
#  ('Soccer European', 2),
#  ('Mega Drive', 2),
#  ('Sony Imagesoft Developer', 2),
#  ('Check', 2),
#  ('Emdy', 2),
#  ('Emotions', 2),
#  ('Tears', 2),
#  ('Natalia Oreiro', 2),
#  ('Beautiful Game', 2),
#  ('Music', 2),
#  ('David Kaposi', 2),
#  ('Jesus', 2),
#  ('Jose', 2),
#  ('Result', 2),
#  ('Strike', 2),
#  ('David Bell', 2),
#  ('Morocco Biggest', 2),
#  ('France Top', 2),
#  ('Penalty', 2),
#  ('Ant', 2),
#  ('France Team', 2),
#  ('Oyub Titiev', 2),
#  ('Goodlcuk', 2),
#  ('TOPICAL', 2),
#  ('FIFA Russia', 2),
#  ('Balls Deep', 2),
#  ('Shoreditch', 2),
#  ('Ulefone', 2),
#  ('FAS', 2),
#  ('Lim Kia Tong', 2),
#  ('BIGGER', 2),
#  ('Caspar', 2),
#  ('KAZANMAYA', 2),
#  ('Best Goal Who', 2),
#  ('Which African', 2),
#  ('Syrian', 2),
#  ('Fashionable', 2),
#  ('Wise Counsel', 2),
#  ('Instagram', 2),
#  ('V', 2),
#  ('Pirates Bay', 2),
#  ('Central Pier', 2),
#  ('Red Square', 2),
#  ('Lighthouse', 2),
#  ('UAE', 2),
#  ('Bahrain', 2),
#  ('Lebanon', 2),
#  ('Arab', 2),
#  ('Nigerian Jersey', 2),
#  ('Please RT', 2),
#  ('ANY', 2),
#  ('Time', 2),
#  ('Kids Football Goal', 2),
#  ('Feng Shiping', 2),
#  ('Handan', 2),
#  ('Hebei Province', 2),
#  ('Ive', 2),
#  ('House Bar', 2),
#  ('Happy Hour', 2),
#  ('Bite HQ', 2),
#  ('New Order', 2),
#  ('Gold', 2),
#  ('Awesome', 2),
#  ('Arrived', 2),
#  ('Real', 2),
#  ('Boozer', 2),
#  ('European Parliament', 2),
#  ('José', 2),
#  ('Row', 2),
#  ('Link MH17', 2),
#  ('Ladbrokes', 2),
#  ('Sensible', 2),
#  ('Swedish', 2),
#  ('NON', 2),
#  ('Historic', 2),
#  ('Gernot Rohr', 2),
#  ('Saransk', 2),
#  ('Malawi', 2),
#  ('Video', 2),
#  ('Saudi Arabia Kick Off', 2),
#  ('Le', 2),
#  ('Sport', 2),
#  ('God', 2),
#  ('Sadio Mane', 2),
#  ('Rashford', 2),
#  ('Guru', 2),
#  ('Perchang', 2),
#  ('Sport Mediaset', 2),
#  ('Ретвитни', 2),
#  ('Nayy', 2),
#  ('Brilliant', 2),
#  ('Look', 2),
#  ('Saudi Arabia Kick', 2),
#  ('TIME', 2),
#  ('Celebrating', 2),
#  ('Gorky Park', 2),
#  ('Legends Bar', 2),
#  ('Pattern', 2),
#  ('Western', 2),
#  ('Martial', 2),
#  ('Thanks', 2),
#  ('Fall', 2),
#  ('Kicker', 2),
#  ('Clap', 2),
#  ('Sony', 2),
#  ('Young', 2),
#  ('Catherine', 2),
#  ('Option', 2),
#  ('Salah', 2),
#  ('Marco', 2),
#  ('Alex', 2),
#  ('MacMafia', 2),
#  ('Arms Trade', 2),
#  ('Match Prediction Russia', 2),
#  ('Saudi Arabia Saudi Arabia', 2),
#  ('Concorde', 2),
#  ('Stock', 2),
#  ('The Viceroy', 2),
#  ('John', 2),
#  ('Vamos Albiceleste', 2),
#  ('YAYYY', 2),
#  ('Leyton Orient', 2),
#  ('Psychic Pig Predicts Nigeria Will Get', 2),
#  ('COME', 2),
#  ('Les Bleus', 2),
#  ('Twinkle Twinkle', 2),
#  ('Koyla Bar', 2),
#  ('FREE Pint', 2),
#  ('Jjaja', 2),
#  ('Hopefully', 2),
#  ('Fallen Dream', 2),
#  ('Team Redtail', 2),
#  ('kWh', 2),
#  ('Harriers', 2),
#  ('Cmon', 2),
#  ('BRAZIL', 2),
#  ('Group H', 2),
#  ('Midway Supermarket', 2),
#  ('Mohamed Salah', 2),
#  ('KICC', 2),
#  ('SPANYOL', 2),
#  ('Piala Dunia', 2),
#  ('Party', 2),
#  ('MESIR', 2),
#  ('URUGUAY', 2),
#  ('Arena', 2),
#  ('International', 2),
#  ('Grenfell', 2),
#  ('St. Petersburg', 2),
#  ('SKOL Malt Football Village', 2),
#  ('Camp Kigali', 2),
#  ('Operations', 2),
#  ('Jason Tauriello', 2),
#  ('Ah', 2),
#  ('Someone', 2),
#  ('Oak', 2),
#  ('La Terrasse Tent', 2),
#  ('Gloria Hotel Dubai', 2),
#  ('Use', 2),
#  ('David', 2),
#  ('Joel Campbell Mohamed', 2),
#  ('Nick GRIMshaw', 2),
#  ('Darby Road Pub', 2),
#  ('ACAS', 2),
#  ('Saudia Arabia', 2),
#  ('Muhaab', 2),
#  ('Machboos', 2),
#  ('MHR', 2),
#  ('Telemundo', 2),
#  ('Only African Country', 2),
#  ('Will Go Furthest', 2),
#  ('Leroy Sane', 2),
#  ('Afcon FC', 2),
#  ('Panini Sticker', 2),
#  ('Official Tournament', 2),
#  ('TONIGHT', 2),
#  ('Vodka', 2),
#  ('FIFA My', 2),
#  ('Spoiler', 2),
#  ('Spanish', 2),
#  ('Island', 2),
#  ('Southgate', 2),
#  ('Facebook', 2),
#  ('Doog', 2),
#  ('Derek Dougan', 2),
#  ('HAPPY', 2),
#  ('Yintoni', 2),
#  ('William Hill', 2),
#  ('TO', 2),
#  ('FIVE', 2),
#  ('AFRICA', 2),
#  ('Colossus Pick6 Correct Score', 2),
#  ('Cristiano', 2),
#  ('Satff', 2),
#  ('George Best', 2),
#  ('Colin Shindler', 2),
#  ('Lagos', 2),
#  ('Zelenogorsk', 2),
#  ('Madrid', 2),
#  ('Curious', 2),
#  ('LOT', 2),
#  ('Ideal Boiler', 2),
#  ('SMG', 2),
#  ('Yang Chao', 2),
#  ('Cathedral', 2),
#  ('Bathong', 2),
#  ('Wao', 2),
#  ('PCG35 Apo', 2),
#  ('Beef Stroganoff', 2),
#  ('Pickled Beetroot', 2),
#  ('Sauerkraut', 2),
#  ('Manchester United', 2),
#  ('Weather', 2),
#  ('Kings Arms High East Street', 2),
#  ('Arsenal', 2),
#  ('Kieran D', 2),
#  ('Stream', 2),
#  ('Goals', 2),
#  ('Ashbridge', 2),
#  ('Bargain Get An Unreal', 2),
#  ('Beat Saudi Arabia', 2),
#  ('WHATS', 2),
#  ('Nick Pope', 2),
#  ('England Football', 2),
#  ('Between', 2),
#  ('Public', 2),
#  ('THE VIBE', 2),
#  ('Vardy', 2),
#  ('Subscribe', 2),
#  ('Tag', 2),
#  ('Kill', 2),
#  ('Scott Wilson', 2),
#  ('BELIEVE Noble', 2),
#  ('Sarah Mains', 2),
#  ('Voting', 2),
#  ('Spikes', 2),
#  ('St', 2),
#  ('Real Madrid', 2),
#  ('Schedule', 2),
#  ('Pride', 2),
#  ('Sooo', 2),
#  ('Socks', 2),
#  ('GOAL', 2),
#  ('Visit Paddy Power', 2),
#  ('Ooh', 2),
#  ('Islam', 2),
#  ('Imagine', 2),
#  ('Podcast One Sports', 2),
#  ('John Barnes', 2),
#  ('Harsham Camp', 2),
#  ('MORE', 2),
#  ('NEDS', 2),
#  ('Get Modern LOGO DESIGN', 2),
#  ('Group Picks', 2),
#  ('Projections', 2),
#  ('COMMENT BELOW', 2),
#  ('SAUDI', 2),
#  ('Whilst', 2),
#  ('WorldCup Plz', 2),
#  ('Donate', 2),
#  ('Help Scott', 2),
#  ('Online Live', 2),
#  ('HUGE', 2),
#  ('Gourmet', 2),
#  ('Good Morning', 2),
#  ('Oxford United', 2),
#  ('Laptops', 2),
#  ('CALL', 2),
#  ('READY', 2),
#  ('Simon', 2),
#  ('Fancy', 2),
#  ('Portual', 2),
#  ('Market Update Crisis', 2),
#  ('Crisis', 2),
#  ('No Deposit Free', 2),
#  ('Ati', 2),
#  ('Tujibambe', 2),
#  ('Radio Times', 2),
#  ('Monty', 2),
#  ('Pup Prediction', 2),
#  ('Roberto Carlos', 2),
#  ('Brazilian', 2),
#  ('Football Shirt', 2),
#  ('Trump', 2),
#  ('Semis', 2),
#  ('Russia Tagliafico', 2),
#  ('Everyman Cut Throat Shave', 2),
#  ('Which Bible', 2),
#  ('Naija', 2),
#  ('Russia Ukrainian', 2),
#  ('Olawale Hamzat', 2),
#  ('Report', 2),
#  ('Fat Panda', 2),
#  ('Goa', 2),
#  ('Got Loads', 2),
#  ('Fun Promotions', 2),
#  ('Prizes', 2),
#  ('Season', 2),
#  ('Twitter Fifa', 2),
#  ('Brazil England', 2),
#  ('Gorgeous', 2),
#  ('Kremlin', 2),
#  ('Wizkid', 2),
#  ('Betfair', 2),
#  ('Vladimir', 2),
#  ('Golden Ball', 2),
#  ('Village', 2),
#  ('Station Hill', 2),
#  ('Katie Hopkins', 2),
#  ('Abuja', 2),
#  ('Swan', 2),
#  ('England Sparrow', 2),
#  ('Era Istrefi', 2),
#  ('Ole Ola', 2),
#  ('Grp C', 2),
#  ('Grp D', 2),
#  ('Brent Crude', 2),
#  ('Hill New Customers Offer', 2),
#  ('FR', 2),
#  ('UHD Video', 2),
#  ('Martin Ron', 2),
#  ('Robin', 2),
#  ('Kikuyu', 2),
#  ('PLUS Check', 2),
#  ('Kylian Mbappé', 2),
#  ('ONE', 2),
#  ('Mohammad', 2),
#  ('Salman', 2),
#  ('Neither Namibia', 2),
#  ('Saudi Arabians', 2),
#  ('Passion', 2),
#  ('Gabriel Jesus', 2),
#  ('Messi Warns Argentina', 2),
#  ('Boycott', 2),
#  ('Know', 2),
#  ('GENTLEMEN', 2),
#  ('Legends', 2),
#  ('Kempes', 2),
#  ('Schillaci', 2),
#  ('Iniesta', 2),
#  ('Anything', 2),
#  ('Puma', 2),
#  ('Language C', 2),
#  ('Hype', 2),
#  ('Headline', 2),
#  ('Bob Iarusci', 2),
#  ('Worst', 2),
#  ('USSR', 2),
#  ('Arabia Tip', 2),
#  ('Irans', 2),
#  ('Port Solent', 2),
#  ('NAEA Propertymark', 2),
#  ('Kickoff', 2),
#  ('Burger Meal', 2),
#  ('Pint', 2),
#  ('SMEG', 2),
#  ('Bulls', 2),
#  ('FFS', 2),
#  ('HIV', 2),
#  ('Grand', 2),
#  ('Vote', 2),
#  ('Canada', 2),
#  ('Merseyside', 2),
#  ('Juan Diego', 1),
#  ('Guadalupe', 1),
#  ('Passle', 1),
#  ('Radio Marca', 1),
#  ('Sergio Ramos', 1),
#  ('Coach', 1),
#  ('Sat', 1),
#  ('Brighton', 1),
#  ('NIGERIA SENEGAL', 1),
#  ('Yahoo Image Search Results', 1),
#  ('SmartMesh', 1),
#  ('SMT Prize Tournament', 1),
#  ('Fan', 1),
#  ('Rode Duivels', 1),
#  ('Nike Football', 1),
#  ('Jersey Shirt Men', 1),
#  ('Yarmer', 1),
#  ('Both', 1),
#  ('Tottenham', 1),
#  ('CET', 1),
#  ('West Coast', 1),
#  ('Thought', 1),
#  ('African European', 1),
#  ('Poor', 1),
#  ('Ayuvedam', 1),
#  ('Langjökull', 1),
#  ('Old Street', 1),
#  ('Mexico86', 1),
#  ('Neville', 1),
#  ('Mackems', 1),
#  ('Dutchman', 1),
#  ('Goaaaaall', 1),
#  ('RSVP', 1),
#  ('Martens', 1),
#  ('Otamendi', 1),
#  ('BOOOOOOOOOOOOM', 1),
#  ('MAJOR LEAGUE', 1),
#  ('PARLAY', 1),
#  ('FUCKING', 1),
#  ('SAN', 1),
#  ('Ricardo Mondragon', 1),
#  ('Glorious Home', 1),
#  ('Jesus Book', 1),
#  ('AMAZON', 1),
#  ('LeBron', 1),
#  ('Al Bilad English Daily', 1),
#  ('Airdrop', 1),
#  ('Hehe No Gender', 1),
#  ('West Asia', 1),
#  ('Soju Sunway', 1),
#  ('Connor', 1),
#  ('SPORTSBET BONUS', 1),
#  ('Brexit', 1),
#  ('Wavin', 1),
#  ('Handmaid', 1),
#  ('Possible', 1),
#  ('Fmd', 1),
#  ('Anfield', 1),
#  ('Excitement', 1),
#  ('Vivid', 1),
#  ('Saudi Arabia Watch', 1),
#  ('ICO', 1),
#  ('Player', 1),
#  ('Alan Dzagoev Age', 1),
#  ('Central Midfield International', 1),
#  ('Gerald Mosse', 1),
#  ('Americain', 1),
#  ('Freelance', 1),
#  ('OUR', 1),
#  ('Again', 1),
#  ('PIN', 1),
#  ('Bosnia-Herzegovina', 1),
#  ('Women', 1),
#  ('Kuntala Ghosh', 1),
#  ('Bodutu', 1),
#  ('ELIGUE', 1),
#  ('League Cup', 1),
#  ('Kings Fantasy', 1),
#  ('Jocks', 1),
#  ('Cell', 1),
#  ('Zwickau', 1),
#  ('Eish', 1),
#  ('Outright Winner Odds', 1),
#  ('Pelé', 1),
#  ('Lil Delivery', 1),
#  ('Dear Ayuvedam', 1),
#  ('Gelut', 1),
#  ('Ryans', 1),
#  ('Supporting Belgium', 1),
#  ('Pennosoft', 1),
#  ('Man', 1),
#  ('The Prince', 1),
#  ('WorldCup Garden', 1),
#  ('Ellen', 1),
#  ('Film', 1),
#  ('Astro', 1),
#  ...]

# %%
print (get_continuous_chunks(txt))
# Out:
# ['England', '']

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Nectec\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Nectec\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# True

# %%
nltk.download('maxent_ne_chunker')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\Nectec\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping chunkers\maxent_ne_chunker.zip.
# True

# %%
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\Nectec\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\words.zip.
# True
