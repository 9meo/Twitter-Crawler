# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

# %%
#driver = webdriver.Firefox(executable_path=r'./geckodriver.exe')
driver = webdriver.Chrome()

# %%
driver.get("https://twitter.com/Thairath_News")

# %%
for i in range(5):
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(1)

# %%
tweets = driver.find_elements_by_class_name('js-tweet-text-container')

# %%
for tw in tweets:
    print(tw.text)
# Out:
# ’เจ้ารณฤทธิ์’ ประสบอุบัติเหตุรถยนต์เจ็บสาหัส พระชายาถึงแก่กรรม
# 'เฉลิมเกียรติ' ลุยถนนข้าวสารคุมเข้มร้านค้า ห้ามมีเล่นพนันบอล
# แผ่นดินไหวเมียนมา 5.2 สะเทือนรู้สึกถึงแม่ฮ่องสอน ยังไม่พบความเสียหาย #แผ่นดินไหว #แผ่นดินไหวเมียนมา #ไทยรัฐ #แม่ฮ่องสอน
# 2 โจ๋ค้ายาโผล่มอบตัว หลังคลิปถูกรุมกระทืบหลุด เผย รู้สึกผวา กลัวถูกฆ่า
# ย้ำเส้นตาย 30 มิ.ย.เร่งแรงงานต่างด้าว ขออนุญาตทำงานทุกขั้นตอนให้เสร็จ
# กระบะพาญาติกลับจากงานศพ พลิกคว่ำเจ็บ 5 ที่กบินทร์บุรี คาดคนขับหลับใน
# ถนนลื่นกระบะสาวใหญ่สงขลา พลิกคว่ำที่ถนนเขาพับผ้า ดับ 1 เจ็บ 2
# 'ป๋าเปรม' เยี่ยมโรงเรียนปาดังติณสูลานนท์ เด็กๆประทับใจ ซาบซึ้งน้ำตานอง
# อัจฉริยะ ปล่อยคลิป 'หวย 30 ล้าน' บอกพูด 10 ครั้ง ไม่เหมือนกันสักครั้ง #หวย30ล้าน #ไทยรัฐ
# หวิดตายหมู่นับสิบ เรือดำน้ำล่มที่ชุมพร โชคดีทีมกู้ภัยมาช่วยทันเวลา
# ครูพลาม วิ่งล่ามโซ่ใส่คอมแบตถึงเบตงแล้ว หวังเห็นคนไทยรักสามัคคีกัน
# บินตรงจากสหรัฐฯ ตามหารถหาย วอน 'บิ๊กโจ๊ก' ที่พึ่งสุดท้าย จับได้ให้ 1 แสน
# แสนเศร้า! ญาติทำพิธีเผาศพน้องกิ๊ฟ เหลือรอผลชันสูตรคาดจะรู้เร็วๆ นี้
# แม่ทัพภาค 4 นำมือวางบึม ขึ้นเขากาหลงยึดถังแก๊สระเบิดแสดงเครื่อง 1 ลูก
# เซอร์ไพรส์! ‘คลอปป์’ เตรียมคว้าตัวรุกแซมบ้า 40 ล้าน (คลิป)
# ฆ่าเปลือยรัดคอสาว ทิ้งหมกคูน้ำที่ปทุมธานี คาดถูกนำศพมาทิ้งอำพราง
# ขอบคุณพุ่มพวง เลขเด็ดมาตรงเผงเฮกันทั่ว แห่นำของมาไหว้แก้บนเพียบ
# พายุถล่มสวนทุเรียนประจวบฯ เก็บไม่ทันร่วงเสียหายยับเยิน
# อะไรกันยังไม่ถึงวันที่ 1 ก.ค.! คนรักหวยแห่จอง 728 766 966 เพียบ #หวย #ไทยรัฐ
# เสียงสุดท้าย! เปิดคลิปบนรถตู้ก่อน 'ผู้จัดการวงลำไย ไหทองคำ' เสียชีวิต #ไทยรัฐ
# ‘ซาฮา’ เดือด! จวกยับ ‘มาร์เชียล’ หลังส่อย้ายหนีผีแดง
# ลุงหมีหัวใจแกร่ง ปั่นวีลแชร์ถึงเมืองคอนแล้ว ชาวบ้านร่วมบริจาคคึกคัก
# พายุฝนถล่มภูเก็ตโดย 3 อำเภอ ต้นไม้โค่น-เสาไฟหัก ป้ายโฆษณาปลิวขวางถนน
# ชำแหละ ตุ๊กๆ-แท็กซี่ ขี้โกง หลอก นทท. ขายทัวร์ อ้างรัฐบาล ยุซื้อของ
# ออกล่าแชมป์! สื่อดังคาด 11 ตัวจริงเยอรมนี เกมฟัดเม็กซิโก
# ย้ายด่วนผอ.ร.ร.ดังที่ขอนแก่น ปมอาหารกลางวัน สั่งสอบข้อเท็จจริงใน7วัน
# ฝนตกหนักทำซากไม้จากป่า ไหลมาติดตอม่อสะพานมอญ เกรงจะทำสะพานพัง
# ถนนกลายเป็นสังเวียน! หนุ่มโดดถีบ-ชกลุงหน้าหงาย หลังขับรถปาดหน้ากัน #ไทยรัฐ
# แชทหลุด! ดราม่า ภาคต่อ #ทำผมแสนสี่ บทสนทนาลูกค้าและคนในร้าน ทวงค่าทำผม ก่อนเกิดเหตุการณ์ ต่อยกันยับกลางตลาด >> https://www.facebook.com/146406732438/posts/10157019312892439/ … #ไทยรัฐ
# ลูกตะกั่วพุ่งถากหัว อาการโคม่า ลูกเสี่ยร้านทองหึงแรง ทำปืนลั่นใส่แฟน
# รถตู้นักดนตรี วงลำไย ไหทองคำ ชนท้ายรถการไฟฟ้าที่พัทลุง ตาย 1 เจ็บอีก 9
# ตะลึง! ‘ชไมเคิล’ ทำลายสถิติคุณพ่อ หลังพาเดนมาร์กเชือดเปรู
# เห็นหายไปนาน! ญาตช็อกเจอลุงชัยนาท ตกเปลญวน จมคูน้ำดับมา 3 วัน
# 'อลงกรณ์' ชี้ ไพรมารี เป็นกุญแจสำคัญ ปฏิรูปพรรค และประชาธิปไตย
# สื่อแฉ ‘เมสซี’ ไม่อยากได้ ‘ซาลาห์’ ร่วมทัพบาร์ซา เพราะ 2 เหตุผล
# สุริยะใส แนะ เห็นด้วย มียุทธศาสตร์ชาติ แต่ต้องไม่เขียนโดยคนกลุ่มเดียว
# เจ็บแขนไม่เท่าเจ็บใจ! หนุ่ม 21 ทะเลาะกับแฟนต่อยกระจกบาดแขนสาหัส
# ถอดออกเดี๋ยวนี้! ชาวเน็ตวอนอีเจี๊ยบ เปลี่ยนรูปโปรไฟล์ อย่าเชียร์บราซิล #สวัสดีบอลโลก #WorldCup #ไทยรัฐ
# 'นพดล' ทำฉันทามติเลือกตั้ง ต้องเคลียร์ชัด 8 เดือน ก่อนเข้าคูหา
# มองขาด! ตำนานผู้ดีชี้ชัด ‘ซาลาห์-ซัวเรซ’ ใครเจ๋งกว่ากัน
